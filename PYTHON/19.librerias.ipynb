# %% [markdown]
# ## Librerías

# %%
from math import sqrt, cos, floor, ceil, asin

numero = 80
raiz_numero = sqrt(numero)
print(raiz_numero)
# Out:
# 8.94427190999916

# %%
import datetime

print(datetime.datetime.today())
# Out:
# 2025-11-17 20:43:33.213965

# %%
import os

print(os.listdir("."))
# Out:
# ['03.funciones_built-in.ipynb', '09.sets.ipynb', '01.intro.ipynb', '12.funcionesBuiltIn.ipynb', '02.variablesytipos.ipynb', '13.list_comprehension.ipynb', '14.control_flow.ipynb', '06.listas.ipynb', '08.diccionarios.ipynb', '07.tuplas.ipynb', '05.strings.ipynb', '04.operadores.ipynb', '19.librerias.ipynb', '10.condicionales.ipynb', '11.bucles.ipynb', '18.OOP.ipynb', '16.funciones_parte_2.ipynb', '15.funciones.ipynb', '17.reduce.ipynb']

# %%
from colorama import Fore, Back, Style
print(Fore.WHITE + 'some red text')
print(Back.MAGENTA + 'and with a green background')
print(Style.BRIGHT + 'and in dim text')
# Out:
# some red text
# and with a green background
# and in dim text

# %%
import PySimpleGUI as sg

# All the stuff inside your window.
layout = [  [sg.Text("What's your name?")],
            [sg.InputText()],
            [sg.Button('Ok'), sg.Button('Cancel')] ]

# Create the Window
window = sg.Window('Hello Example', layout)

# Event Loop to process "events" and get the "values" of the inputs
while True:
    event, values = window.read()

    # if user closes window or clicks cancel
    if event == sg.WIN_CLOSED or event == 'Cancel':
        break

    print('Hello', values[0], '!')

window.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       1 import PySimpleGUI as sg
#       3 # All the stuff inside your window.
# ----> 4 layout = [  [sg.Text("What's your name?")],
#       5             [sg.InputText()],
#       6             [sg.Button('Ok'), sg.Button('Cancel')] ]
#       8 # Create the Window
#       9 window = sg.Window('Hello Example', layout)
#
# AttributeError: module 'PySimpleGUI' has no attribute 'Text'
